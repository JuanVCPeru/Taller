# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanVCPeru/Taller/blob/main/Pregunta_2_Examen_Parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pregunta 2 Examen Parcial

# %%
import pandas as pd
df = pd.read_csv('/content/ResearchRabbit_Export_1725123890.csv')
df
# Out:
#                                  DOI        PMID  arXiv ID  \
# 0                                NaN         NaN       NaN
# 1                                NaN         NaN       NaN
# 2                                NaN         NaN       NaN
# 3                                NaN         NaN       NaN
# 4      10.1016/s0027-9684(15)31205-0  18300534.0       NaN
# ...                              ...         ...       ...
# 1001                             NaN         NaN       NaN
# 1002      10.1177/001440298705400305         NaN       NaN
# 1003  10.1080/08886504.1990.10781940         NaN       NaN
# 1004              10.1007/bf01320076         NaN       NaN
# 1005                             NaN         NaN       NaN
#
#                                                   Title  \
# 0     Multimedia in Political Science: Sobering Less...
# 1     Student involvement: A developmental theory fo...
# 2     Using Learning-Styles Data To Design a Microbi...
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada tipo de publicación y ordenar los datos por el índice
subtype_description = df['Year'].value_counts()

# Crear el gráfico de barras con coloración por tipo de publicación
ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# Agregar etiquetas y título
plt.ylabel('Año')
plt.title('Cantidad')

# Formatear el eje y con un decimal
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f'))

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-2-f3083405d71f>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada tipo de publicación y ordenar los datos por el índice
subtype_description = df['Year'].value_counts()

# Crear el gráfico de barras horizontal
plt.barh(subtype_description.index, subtype_description.values) # Pass the values as widths

# Agregar etiquetas y título
plt.ylabel('Año')
plt.title('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
